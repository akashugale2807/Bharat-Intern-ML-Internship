# %% [markdown]
# # Akash Ugale
#
# ## Bharat Intern Machine learning Internship
#
# ### Project 2:- Wine Quality Prediction Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
winedf = pd.read_csv('G:\\Projects\\Bharat Intern Projects\\Wine Quality Prediction\\winequality.csv')
winedf
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
winedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
winedf.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
winedf.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
winedf = winedf.fillna(winedf.mean())

# %%
winedf.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
winedf.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
sb.violinplot(x='quality', y='alcohol', data=winedf)
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.title('Violin Plot: Alcohol vs Quality')
plt.show()

# %%
print(winedf.groupby('quality').size())
# Out:
# quality
# 3      30
# 4     216
# 5    2138
# 6    2836
# 7    1079
# 8     193
# 9       5
# dtype: int64

# %%
plt.figure(figsize=(8,8))
sb.heatmap(winedf.corr(), annot=True, cbar=True)
plt.show()

# %%
plt.figure(figsize=(8,8))
sb.heatmap(winedf.corr() > 0.7, annot=True, cbar=True)
plt.show()

# %%
winedf = winedf.drop('total sulfur dioxide', axis=1)

# %%
winedf.head(5)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0      0.045                 45.0   1.0010  3.00       0.45      8.8        6
# 1      0.049                 14.0   0.9940  3.30       0.49      9.5        6
# 2      0.050                 30.0   0.9951  3.26       0.44     10.1        6
# 3      0.058                 47.0   0.9956  3.19       0.40      9.9        6
# 4      0.058                 47.0   0.9956  3.19       0.40      9.9        6

# %%
winedf['best quality'] = [1 if x > 5 else 0 for x in winedf.quality]
winedf.replace({'white': 1, 'red': 0}, inplace=True)
winedf.head(5)
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1            7.0              0.27         0.36            20.7
# 1     1            6.3              0.30         0.34             1.6
# 2     1            8.1              0.28         0.40             6.9
# 3     1            7.2              0.23         0.32             8.5
# 4     1            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  density    pH  sulphates  alcohol  quality  \
# 0      0.045                 45.0   1.0010  3.00       0.45      8.8        6
# 1      0.049                 14.0   0.9940  3.30       0.49      9.5        6
# 2      0.050                 30.0   0.9951  3.26       0.44     10.1        6
# 3      0.058                 47.0   0.9956  3.19       0.40      9.9        6
# 4      0.058                 47.0   0.9956  3.19       0.40      9.9        6
#
#    best quality
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
winedf['type'].value_counts()
# Out:
# 1    4898
# 0    1599
# Name: type, dtype: int64

# %%
winedf['best quality'].value_counts()
# Out:
# 1    4113
# 0    2384
# Name: best quality, dtype: int64

# %%
winedf = winedf.drop('quality', axis=1)
winedf.head(5)
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1            7.0              0.27         0.36            20.7
# 1     1            6.3              0.30         0.34             1.6
# 2     1            8.1              0.28         0.40             6.9
# 3     1            7.2              0.23         0.32             8.5
# 4     1            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  density    pH  sulphates  alcohol  \
# 0      0.045                 45.0   1.0010  3.00       0.45      8.8
# 1      0.049                 14.0   0.9940  3.30       0.49      9.5
# 2      0.050                 30.0   0.9951  3.26       0.44     10.1
# 3      0.058                 47.0   0.9956  3.19       0.40      9.9
# 4      0.058                 47.0   0.9956  3.19       0.40      9.9
#
#    best quality
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

features = winedf.drop(['best quality'], axis=1)
target = winedf['best quality']
 
xtrain, xtest, ytrain, ytest = train_test_split(
    features, target, test_size=0.2, random_state=40)
 
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((5197, 11), (1300, 11), (5197,), (1300,))

# %%
norm = MinMaxScaler()
xtrain = norm.fit_transform(xtrain)
xtest = norm.transform(xtest)

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import plot_confusion_matrix, accuracy_score, confusion_matrix, classification_report

logreg = LogisticRegression()
logreg.fit(xtrain, ytrain)

train_predictions = logreg.predict(xtrain)
test_predictions = logreg.predict(xtest)

train_accuracy = accuracy_score(ytrain, train_predictions)
test_accuracy = accuracy_score(ytest, test_predictions)

plt.figure(figsize=(1,1))
plot_confusion_matrix(logreg, xtrain, ytrain)
plt.title('Training Confusion Matrix')
plt.show()

plt.figure(figsize=(1,1))
plot_confusion_matrix(logreg, xtest, ytest)
plt.title('Testing Confusion Matrix')
plt.show()

classification_rep = classification_report(ytest, test_predictions)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)

print("\nClassification Report:")
print(classification_rep)
# Out:
# Training Accuracy: 0.7411968443332692
# Testing Accuracy: 0.7376923076923076
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.53      0.60       474
#            1       0.76      0.86      0.81       826
#
#     accuracy                           0.74      1300
#    macro avg       0.72      0.69      0.70      1300
# weighted avg       0.73      0.74      0.73      1300

# %%
# Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier()
rf_classifier.fit(xtrain, ytrain)

train_predictions = rf_classifier.predict(xtrain)
test_predictions = rf_classifier.predict(xtest)

train_accuracy = accuracy_score(ytrain, train_predictions)
test_accuracy = accuracy_score(ytest, test_predictions)

plt.figure(figsize=(1,1))
plot_confusion_matrix(rf_classifier, xtrain, ytrain)
plt.title('Training Confusion Matrix')
plt.show()

plt.figure(figsize=(1,1))
plot_confusion_matrix(rf_classifier, xtest, ytest)
plt.title('Testing Confusion Matrix')
plt.show()

classification_rep = classification_report(ytest, test_predictions)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)

print("\nClassification Report:")
print(classification_rep)
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.8361538461538461
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.72      0.76       474
#            1       0.85      0.90      0.88       826
#
#     accuracy                           0.84      1300
#    macro avg       0.83      0.81      0.82      1300
# weighted avg       0.83      0.84      0.83      1300

# %%
# Support Vector Machines (SVM)

from sklearn.svm import SVC

svm_classifier = SVC()
svm_classifier.fit(xtrain, ytrain)

train_predictions = svm_classifier.predict(xtrain)
test_predictions = svm_classifier.predict(xtest)

train_accuracy = accuracy_score(ytrain, train_predictions)
test_accuracy = accuracy_score(ytest, test_predictions)

plt.figure(figsize=(1,1))
plot_confusion_matrix(svm_classifier, xtrain, ytrain)
plt.title('Training Confusion Matrix')
plt.show()

plt.figure(figsize=(1,1))
plot_confusion_matrix(svm_classifier, xtest, ytest)
plt.title('Testing Confusion Matrix')
plt.show()

classification_rep = classification_report(ytest, test_predictions)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)

print("\nClassification Report:")
print(classification_rep)
# Out:
# Training Accuracy: 0.7512026168943622
# Testing Accuracy: 0.7453846153846154
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.51      0.59       474
#            1       0.76      0.88      0.81       826
#
#     accuracy                           0.75      1300
#    macro avg       0.73      0.70      0.70      1300
# weighted avg       0.74      0.75      0.73      1300

# %%
# K-Nearest Neighbors (KNN)

from sklearn.neighbors import KNeighborsClassifier

knn_classifier = KNeighborsClassifier()
knn_classifier.fit(xtrain, ytrain)

train_predictions = knn_classifier.predict(xtrain)
test_predictions = knn_classifier.predict(xtest)

train_accuracy = accuracy_score(ytrain, train_predictions)
test_accuracy = accuracy_score(ytest, test_predictions)

plt.figure(figsize=(1,1))
plot_confusion_matrix(knn_classifier, xtrain, ytrain)
plt.title('Training Confusion Matrix')
plt.show()

plt.figure(figsize=(1,1))
plot_confusion_matrix(knn_classifier, xtest, ytest)
plt.title('Testing Confusion Matrix')
plt.show()

classification_rep = classification_report(ytest, test_predictions)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)

print("\nClassification Report:")
print(classification_rep)
# Out:
# Training Accuracy: 0.8347123340388686
# Testing Accuracy: 0.7523076923076923
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.62      0.64       474
#            1       0.79      0.83      0.81       826
#
#     accuracy                           0.75      1300
#    macro avg       0.73      0.72      0.73      1300
# weighted avg       0.75      0.75      0.75      1300

# %%
# Gradient Boosting Classifier

from sklearn.ensemble import GradientBoostingClassifier

gb_classifier = GradientBoostingClassifier()
gb_classifier.fit(xtrain, ytrain)

train_predictions = gb_classifier.predict(xtrain)
test_predictions = gb_classifier.predict(xtest)

train_accuracy = accuracy_score(ytrain, train_predictions)
test_accuracy = accuracy_score(ytest, test_predictions)

plt.figure(figsize=(1,1))
plot_confusion_matrix(gb_classifier, xtrain, ytrain)
plt.title('Training Confusion Matrix')
plt.show()

plt.figure(figsize=(1,1))
plot_confusion_matrix(gb_classifier, xtest, ytest)
plt.title('Testing Confusion Matrix')
plt.show()

classification_rep = classification_report(ytest, test_predictions)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)

print("\nClassification Report:")
print(classification_rep)
# Out:
# Training Accuracy: 0.7993072926688474
# Testing Accuracy: 0.7623076923076924
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.58      0.64       474
#            1       0.78      0.87      0.82       826
#
#     accuracy                           0.76      1300
#    macro avg       0.75      0.72      0.73      1300
# weighted avg       0.76      0.76      0.76      1300
